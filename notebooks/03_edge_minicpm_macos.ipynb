# %% [markdown]
# # Edge MiniCPM-V on macOS
#
# Runs MiniCPM-V (4-bit GGUF) fully locally — no network required.
# This is the macOS proxy for the iPhone benchmark in CLAUDE.md §1.

# %%
# Requires: uv pip install -e '.[edge]' && bash scripts/download_minicpm_gguf.sh

# %%
# Placeholder — implemented in task 05
print('Edge backend not yet implemented. See tasks/05-edge-backend-minicpm.md')
