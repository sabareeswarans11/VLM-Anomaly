# %% [markdown]
# # Report Generator
#
# Generates `REPORT.md` with the leaderboard table, all plots (PNG + SVG), and the narrative blurb from CLAUDE.md §13.2.

# %%
# Placeholder — implemented in task 09
print('Report generator not yet implemented. See tasks/09-visualization-and-report.md')
