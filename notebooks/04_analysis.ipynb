# %% [markdown]
# # Results Analysis
#
# Aggregates all JSONs under `results/` using DuckDB and produces the leaderboard table and statistical tests.

# %%
# Placeholder — implemented in task 08
print('Aggregator not yet implemented. See tasks/08-aggregator-analysis.md')

# %% [markdown]
# ## Sample query shape
#
# ```python
# import duckdb
# db = duckdb.connect()
# db.execute("CREATE TABLE r AS SELECT * FROM read_json_auto('results/*.json')")
# db.sql("SELECT model_id, AVG(auroc) FROM r GROUP BY model_id ORDER BY 2 DESC").df()
# ```
